# %%
import pandas as pd
print("Pandas loaded!")
# Out:
# Pandas loaded!

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
import pandas as pd

df = pd.read_csv("../data/raw/fake_social_media.csv")

# %%
print(df.head())
# Out:
#     platform  has_profile_pic  bio_length  username_randomness  followers  \
# 0    Twitter                1         180                    1        431
# 1  Instagram                1         214                    0        426
# 2    Twitter                1          87                    0        426
# 3    Twitter                0          72                    0        385
# 4  Instagram                0         162                    1        392
#
#    following  follower_following_ratio  account_age_days  posts  \
# 0        679                  0.633824               941    194
# 1        729                  0.583562              3164    202
# 2        721                  0.590028               903    225
# 3        679                  0.566176              3433    175
# 4        709                  0.552113              1269    207
#
#    posts_per_day  caption_similarity_score  content_similarity_score  \
# ...

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\DELL\Documents\GitHub\ProSpy\notebooks

# %%
import os

print(os.listdir("../data"))
# Out:
# ['processed', 'raw', 'Sample']

# %%
import os

print(os.listdir("../data/raw"))
# Out:
# ['.gitkeep', 'fake_social_media.csv']

# %%
print(df.head())
# Out:
#     platform  has_profile_pic  bio_length  username_randomness  followers  \
# 0    Twitter                1         180                    1        431
# 1  Instagram                1         214                    0        426
# 2    Twitter                1          87                    0        426
# 3    Twitter                0          72                    0        385
# 4  Instagram                0         162                    1        392
#
#    following  follower_following_ratio  account_age_days  posts  \
# 0        679                  0.633824               941    194
# 1        729                  0.583562              3164    202
# 2        721                  0.590028               903    225
# 3        679                  0.566176              3433    175
# 4        709                  0.552113              1269    207
#
#    posts_per_day  caption_similarity_score  content_similarity_score  \
# ...

# %%
print(df.shape)
# Out:
# (3000, 18)

# %%
print(df.columns)
# Out:
# Index(['platform', 'has_profile_pic', 'bio_length', 'username_randomness',
#        'followers', 'following', 'follower_following_ratio',
#        'account_age_days', 'posts', 'posts_per_day',
#        'caption_similarity_score', 'content_similarity_score',
#        'follow_unfollow_rate', 'spam_comments_rate', 'generic_comment_rate',
#        'suspicious_links_in_bio', 'verified', 'is_fake'],
#       dtype='str')

# %%
print(df.isnull().sum())
# Out:
# platform                    0
# has_profile_pic             0
# bio_length                  0
# username_randomness         0
# followers                   0
# following                   0
# follower_following_ratio    0
# account_age_days            0
# posts                       0
# posts_per_day               0
# caption_similarity_score    0
# content_similarity_score    0
# follow_unfollow_rate        0
# spam_comments_rate          0
# generic_comment_rate        0
# suspicious_links_in_bio     0
# verified                    0
# is_fake                     0
# dtype: int64

# %%
print("Duplicate :", df.duplicated().sum())
# Out:
# Duplicate : 0

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   platform                  3000 non-null   str
#  1   has_profile_pic           3000 non-null   int64
#  2   bio_length                3000 non-null   int64
#  3   username_randomness       3000 non-null   int64
#  4   followers                 3000 non-null   int64
#  5   following                 3000 non-null   int64
#  6   follower_following_ratio  3000 non-null   float64
#  7   account_age_days          3000 non-null   int64
#  8   posts                     3000 non-null   int64
#  9   posts_per_day             3000 non-null   float64
#  10  caption_similarity_score  3000 non-null   float64
#  11  content_similarity_score  3000 non-null   float64
#  12  follow_unfollow_rate      3000 non-null   int64
#  13  spam_comments_rate        3000 non-null   int64
# ...

# %%
print((df['followers']<0).sum())
print((df['following']<0).sum())
# Out:
# 0
# 0

# %%
print(df.describe())
# Out:
#        has_profile_pic   bio_length  username_randomness    followers  \
# count      3000.000000  3000.000000          3000.000000  3000.000000
# mean          0.489333   125.230667             0.506667   399.933667
# std           0.499970    71.511133             0.500039    20.044846
# min           0.000000     0.000000             0.000000   334.000000
# 25%           0.000000    66.000000             0.000000   386.000000
# 50%           0.000000   125.000000             1.000000   400.000000
# 75%           1.000000   186.000000             1.000000   413.000000
# max           1.000000   249.000000             1.000000   472.000000
#
#         following  follower_following_ratio  account_age_days        posts  \
# count  3000.00000               3000.000000       3000.000000  3000.000000
# mean    700.67300                  0.570725       2492.011000   200.255333
# std      25.89729                  0.035164       1431.539864    14.270530
# ...

# %%
df.to_csv(
    "../data/processed/cleaned_fake_social_media.csv",
    index=False
)
